# %% [markdown]
# <a href="https://colab.research.google.com/github/AngC1998/WiDS-Datathon-2025/blob/main/WiDS_Datathon_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
training_solutions_df = pd.read_excel('/content/TRAINING_SOLUTIONS.xlsx')
training_solutions_df
# Out:
#      participant_id  ADHD_Outcome  Sex_F
# 0      UmrK0vMLopoR             1      1
# 1      CPaeQkhcjg7d             1      0
# 2      Nb4EetVPm3gs             1      0
# 3      p4vPhVu91o4b             1      1
# 4      M09PXs7arQ5E             1      1
# ...             ...           ...    ...
# 1208   Atx7oub96GXS             0      0
# 1209   groSbUfkQngM             0      1
# 1210   zmxGvIrOD0bt             0      1
# 1211   rOmWFuJCud5G             0      0
# 1212   k8HhHnnu2wmt             0      0
#
# [1213 rows x 3 columns]

# %%
adhd_count = training_solutions_df.groupby('ADHD_Outcome').count()['participant_id']
adhd_count = adhd_count.to_frame()
adhd_count
# Out:
#               participant_id
# ADHD_Outcome
# 0                        382
# 1                        831

# %%
sns.barplot(x='ADHD_Outcome', y='participant_id', data=adhd_count)
# Out:
# <Axes: xlabel='ADHD_Outcome', ylabel='participant_id'>

# %%
training_solutions_df.isna().any()
# Out:
# participant_id    False
# ADHD_Outcome      False
# Sex_F             False
# dtype: bool

# %%
sex_count = training_solutions_df.groupby('Sex_F').count()['participant_id']
sex_count = sex_count.to_frame()
sex_count
# Out:
#        participant_id
# Sex_F
# 0                 797
# 1                 416

# %%
sns.barplot(x='Sex_F', y='participant_id', data=sex_count)
# Out:
# <Axes: xlabel='Sex_F', ylabel='participant_id'>

# %%
train_categorical_df = pd.read_excel('/content/TRAIN_CATEGORICAL_METADATA_new.xlsx')
train_categorical_df
# Out:
#      participant_id  Basic_Demos_Enroll_Year  Basic_Demos_Study_Site  \
# 0      00aIpNTbG5uh                     2019                       4
# 1      00fV0OyyoLfw                     2017                       1
# 2      04X1eiS79T4B                     2017                       1
# 3      05ocQutkURd6                     2018                       1
# 4      06YUNBA9ZRLq                     2018                       1
# ...             ...                      ...                     ...
# 1208   zwjJWCRzKhDz                     2019                       4
# 1209   zwXD5v17Rx01                     2018                       1
# 1210   zWzLCi3NTBTd                     2018                       3
# 1211   Zy9GTHDxUbXU                     2019                       4
# 1212   Zye7yYRQohXi                     2017                       1
#
#       PreInt_Demos_Fam_Child_Ethnicity  PreInt_Demos_Fam_Child_Race  \
# 0                                  1.0                          0.0
# ...

# %%
train_categorical_df.isna().any()
# Out:
# participant_id                      False
# Basic_Demos_Enroll_Year             False
# Basic_Demos_Study_Site              False
# PreInt_Demos_Fam_Child_Ethnicity     True
# PreInt_Demos_Fam_Child_Race          True
# MRI_Track_Scan_Location              True
# Barratt_Barratt_P1_Edu               True
# Barratt_Barratt_P1_Occ               True
# Barratt_Barratt_P2_Edu               True
# Barratt_Barratt_P2_Occ               True
# dtype: bool

# %%
year_count = train_categorical_df.groupby('Basic_Demos_Enroll_Year').count()['participant_id']
year_count = year_count.to_frame()
year_count
# Out:
#                          participant_id
# Basic_Demos_Enroll_Year
# 2015                                 36
# 2016                                191
# 2017                                254
# 2018                                415
# 2019                                312
# 2020                                  5

# %%
sns.barplot(x='Basic_Demos_Enroll_Year', y='participant_id', data=year_count)
# Out:
# <Axes: xlabel='Basic_Demos_Enroll_Year', ylabel='participant_id'>

# %%
site_count = train_categorical_df.groupby('Basic_Demos_Study_Site').count()['participant_id']
site_count = site_count.to_frame()
site_count
# Out:
#                         participant_id
# Basic_Demos_Study_Site
# 1                                  652
# 2                                   11
# 3                                  430
# 4                                  120

# %%
sns.barplot(x='Basic_Demos_Study_Site', y='participant_id', data=site_count)
# Out:
# <Axes: xlabel='Basic_Demos_Study_Site', ylabel='participant_id'>

# %%
ethnicity_count = train_categorical_df.groupby('PreInt_Demos_Fam_Child_Ethnicity').count()['participant_id']
ethnicity_count = ethnicity_count.to_frame()
ethnicity_count
# Out:
#                                   participant_id
# PreInt_Demos_Fam_Child_Ethnicity
# 0.0                                          777
# 1.0                                          296
# 2.0                                           77
# 3.0                                           20

# %%
sns.barplot(x='PreInt_Demos_Fam_Child_Ethnicity', y='participant_id', data=ethnicity_count)
# Out:
# <Axes: xlabel='PreInt_Demos_Fam_Child_Ethnicity', ylabel='participant_id'>

# %%
race_count = train_categorical_df.groupby('PreInt_Demos_Fam_Child_Race').count()['participant_id']
race_count = race_count.to_frame()
race_count
# Out:
#                              participant_id
# PreInt_Demos_Fam_Child_Race
# 0.0                                     573
# 1.0                                     181
# 2.0                                     128
# 3.0                                      30
# 4.0                                      10
# 7.0                                       2
# 8.0                                     195
# 9.0                                      23
# 10.0                                     11
# 11.0                                      6

# %%
sns.barplot(x='PreInt_Demos_Fam_Child_Race', y='participant_id', data=race_count)
# Out:
# <Axes: xlabel='PreInt_Demos_Fam_Child_Race', ylabel='participant_id'>

# %%
location_count = train_categorical_df.groupby('MRI_Track_Scan_Location').count()['participant_id']
location_count = location_count.to_frame()
location_count
# Out:
#                          participant_id
# MRI_Track_Scan_Location
# 1.0                                 179
# 2.0                                 532
# 3.0                                 463
# 4.0                                  36

# %%
sns.barplot(x='MRI_Track_Scan_Location', y='participant_id', data=location_count)
# Out:
# <Axes: xlabel='MRI_Track_Scan_Location', ylabel='participant_id'>

# %%
p1_edu_count = train_categorical_df.groupby('Barratt_Barratt_P1_Edu').count()['participant_id']
p1_edu_count = p1_edu_count.to_frame()
p1_edu_count
# Out:
#                         participant_id
# Barratt_Barratt_P1_Edu
# 3.0                                  5
# 6.0                                 15
# 9.0                                 28
# 12.0                                97
# 15.0                               162
# 18.0                               421
# 21.0                               470

# %%
sns.barplot(x='Barratt_Barratt_P1_Edu', y='participant_id', data=p1_edu_count)
# Out:
# <Axes: xlabel='Barratt_Barratt_P1_Edu', ylabel='participant_id'>

# %%
p1_occ_count = train_categorical_df.groupby('Barratt_Barratt_P1_Occ').count()['participant_id']
p1_occ_count = p1_occ_count.to_frame()
p1_occ_count
# Out:
#                         participant_id
# Barratt_Barratt_P1_Occ
# 0.0                                286
# 5.0                                 31
# 10.0                                 6
# 15.0                                35
# 20.0                                31
# 25.0                                79
# 30.0                               154
# 35.0                               219
# 40.0                               154
# 45.0                               187

# %%
sns.barplot(x='Barratt_Barratt_P1_Occ', y='participant_id', data=p1_occ_count)
# Out:
# <Axes: xlabel='Barratt_Barratt_P1_Occ', ylabel='participant_id'>

# %%
p2_edu_count = train_categorical_df.groupby('Barratt_Barratt_P2_Edu').count()['participant_id']
p2_edu_count = p2_edu_count.to_frame()
p2_edu_count
# Out:
#                         participant_id
# Barratt_Barratt_P2_Edu
# 3.0                                  5
# 6.0                                 14
# 9.0                                 44
# 12.0                               162
# 15.0                               166
# 18.0                               301
# 21.0                               323

# %%
sns.barplot(x='Barratt_Barratt_P2_Edu', y='participant_id', data=p2_edu_count)
# Out:
# <Axes: xlabel='Barratt_Barratt_P2_Edu', ylabel='participant_id'>

# %%
p2_occ_count = train_categorical_df.groupby('Barratt_Barratt_P2_Occ').count()['participant_id']
p2_occ_count = p2_occ_count.to_frame()
p2_occ_count
# Out:
#                         participant_id
# Barratt_Barratt_P2_Occ
# 0.0                                 65
# 5.0                                 38
# 10.0                                37
# 15.0                                86
# 20.0                                41
# 25.0                                25
# 30.0                               149
# 35.0                               195
# 40.0                               116
# 45.0                               239

# %%
sns.barplot(x='Barratt_Barratt_P2_Occ', y='participant_id', data=p2_occ_count)
# Out:
# <Axes: xlabel='Barratt_Barratt_P2_Occ', ylabel='participant_id'>

# %%
train_categorical_df.columns
# Out:
# Index(['participant_id', 'Basic_Demos_Enroll_Year', 'Basic_Demos_Study_Site',
#        'PreInt_Demos_Fam_Child_Ethnicity', 'PreInt_Demos_Fam_Child_Race',
#        'MRI_Track_Scan_Location', 'Barratt_Barratt_P1_Edu',
#        'Barratt_Barratt_P1_Occ', 'Barratt_Barratt_P2_Edu',
#        'Barratt_Barratt_P2_Occ'],
#       dtype='object')

# %%
train_functional_df = pd.read_csv('/content/TRAIN_FUNCTIONAL_CONNECTOME_MATRICES_new_36P_Pearson.csv')
train_functional_df
# Out:
#      participant_id  0throw_1thcolumn  0throw_2thcolumn  0throw_3thcolumn  \
# 0      70z8Q2xdTXM3          0.222930          0.527903          0.429966
# 1      WHWymJu6zNZi          0.614765          0.577255          0.496127
# 2      4PAQp1M6EyAo         -0.116833          0.458408          0.260703
# 3      obEacy4Of68I          0.199688          0.752714          0.658283
# 4      s7WzzDcmDOhF          0.227321          0.613268          0.621447
# ...             ...               ...               ...               ...
# 1208   9gpepMI9sj5q          0.265284          0.551726          0.628318
# 1209   FIDen5rdMc0v         -0.018377          0.576689          0.527451
# 1210   dlsMC4TXL4e8          0.227028          0.405659          0.023545
# 1211   syeyZjEx8FUx          0.189849          0.752876          0.842463
# 1212   wWZUoBUOOXhT          0.165500          0.779444          0.686992
#
#       0throw_4thcolumn  0throw_5thcolumn  0throw_6thcolumn  0throw_7thcolumn  \
# ...

# %%
train_functional_df.isna().any()
# Out:
# participant_id          False
# 0throw_1thcolumn        False
# 0throw_2thcolumn        False
# 0throw_3thcolumn        False
# 0throw_4thcolumn        False
#                         ...
# 196throw_198thcolumn    False
# 196throw_199thcolumn    False
# 197throw_198thcolumn    False
# 197throw_199thcolumn    False
# 198throw_199thcolumn    False
# Length: 19901, dtype: bool

# %%
train_functional_df.isna().any().any()
# Out:
# np.False_

# %%
train_quantitative_df = pd.read_excel('/content/TRAIN_QUANTITATIVE_METADATA_new.xlsx')
train_quantitative_df
# Out:
#      participant_id  EHQ_EHQ_Total  ColorVision_CV_Score  APQ_P_APQ_P_CP  \
# 0      00aIpNTbG5uh         100.00                  13.0             3.0
# 1      00fV0OyyoLfw          92.27                  14.0             3.0
# 2      04X1eiS79T4B          86.67                  14.0             3.0
# 3      05ocQutkURd6          93.34                  14.0             3.0
# 4      06YUNBA9ZRLq           0.00                  14.0             8.0
# ...             ...            ...                   ...             ...
# 1208   zwjJWCRzKhDz         100.00                  14.0             3.0
# 1209   zwXD5v17Rx01          46.67                  14.0             3.0
# 1210   zWzLCi3NTBTd         -40.00                  14.0             3.0
# 1211   Zy9GTHDxUbXU         100.00                  14.0             3.0
# 1212   Zye7yYRQohXi          87.80                  14.0             3.0
#
#       APQ_P_APQ_P_ID  APQ_P_APQ_P_INV  APQ_P_APQ_P_OPD  APQ_P_APQ_P_PM  \
# ...

# %%
train_quantitative_df.isna().any()
# Out:
# participant_id                False
# EHQ_EHQ_Total                  True
# ColorVision_CV_Score           True
# APQ_P_APQ_P_CP                 True
# APQ_P_APQ_P_ID                 True
# APQ_P_APQ_P_INV                True
# APQ_P_APQ_P_OPD                True
# APQ_P_APQ_P_PM                 True
# APQ_P_APQ_P_PP                 True
# SDQ_SDQ_Conduct_Problems       True
# SDQ_SDQ_Difficulties_Total     True
# SDQ_SDQ_Emotional_Problems     True
# SDQ_SDQ_Externalizing          True
# SDQ_SDQ_Generating_Impact      True
# SDQ_SDQ_Hyperactivity          True
# SDQ_SDQ_Internalizing          True
# SDQ_SDQ_Peer_Problems          True
# SDQ_SDQ_Prosocial              True
# MRI_Track_Age_at_Scan          True
# dtype: bool

# %%
train_quantitative_df.columns
# Out:
# Index(['participant_id', 'EHQ_EHQ_Total', 'ColorVision_CV_Score',
#        'APQ_P_APQ_P_CP', 'APQ_P_APQ_P_ID', 'APQ_P_APQ_P_INV',
#        'APQ_P_APQ_P_OPD', 'APQ_P_APQ_P_PM', 'APQ_P_APQ_P_PP',
#        'SDQ_SDQ_Conduct_Problems', 'SDQ_SDQ_Difficulties_Total',
#        'SDQ_SDQ_Emotional_Problems', 'SDQ_SDQ_Externalizing',
#        'SDQ_SDQ_Generating_Impact', 'SDQ_SDQ_Hyperactivity',
#        'SDQ_SDQ_Internalizing', 'SDQ_SDQ_Peer_Problems', 'SDQ_SDQ_Prosocial',
#        'MRI_Track_Age_at_Scan'],
#       dtype='object')

# %%
train_quantitative_df.plot.hist(column='EHQ_EHQ_Total')
# Out:
# <Axes: ylabel='Frequency'>

# %%
train_quantitative_df.plot.hist(column='ColorVision_CV_Score')
# Out:
# <Axes: ylabel='Frequency'>

# %%
train_quantitative_df.plot.hist(column='APQ_P_APQ_P_CP')
# Out:
# <Axes: ylabel='Frequency'>
